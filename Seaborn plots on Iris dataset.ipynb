# %%
import seaborn as sns
import pandas as pd
# %mathplotlib inline
#import mathplot.pyplot as plt
# Out:
# UsageError: Line magic function `%mathplotlib` not found.

# %%
import os
os.chdir("D:\\GEGDC\\KT00475829\\Iris dataset")

# %%
iris = pd.read_csv("Iris.csv")

# %%
iris.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width','class']

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
import IPython
print(IPython.sys_info())
# Out:
# {'commit_hash': 'dd83a2163',
#  'commit_source': 'installation',
#  'default_encoding': '1252',
#  'ipython_path': 'D:\\GEGDC\\KT00475829\\Anaconda\\lib\\site-packages\\IPython',
#  'ipython_version': '6.5.0',
#  'os_name': 'nt',
#  'platform': 'Windows-7-6.1.7601-SP1',
#  'sys_executable': 'D:\\GEGDC\\KT00475829\\Anaconda\\python.exe',
#  'sys_platform': 'win32',
#  'sys_version': '3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit '
#                 '(AMD64)]'}

# %%
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', data = iris, size=20)

# %%
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', hue = 'class', data = iris, size=20)

# %%
iris['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', hue = 'class', data = iris, legend='full',size='class')

# %%
#Lineplot
sns.relplot(x = 'petal_length', y = 'petal_width', kind = 'line', data=iris)
# Out:
# D:\GEGDC\KT00475829\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.relplot(x = 'petal_length', y = 'petal_width', kind = 'line', data=iris, ci = None)

# %%
sns.relplot(x = 'petal_length', y = 'petal_width', kind = 'line', data=iris, ci = None, hue = 'class')

# %%
sns.relplot(x = 'petal_length', y = 'petal_width', kind = 'line', data=iris, ci = None, col = 'class')

# %%
os.chdir("D:\\GEGDC\\KT00475829\\Downloads\\telco-customer-churn")

# %%
churn = pd.read_csv("Churn.csv")

# %%
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
col = churn.columns

# %%
#Plotting catagorical values
sns.catplot(x = 'Churn', y = 'MonthlyCharges', data=churn)

# %%
sns.catplot(x = 'Churn', y = 'MonthlyCharges', data=churn, kind='swarm')

# %%
sns.catplot(x = 'Churn', y = 'MonthlyCharges', data=churn, kind='swarm', hue='PaperlessBilling')

# %%
sns.catplot(x = 'Churn', y = 'MonthlyCharges', data=churn, kind='swarm', hue='PaperlessBilling', order=['Yes', 'No'])

# %%
churn['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
#Boxplots
sns.boxplot(x = 'PaymentMethod', y = 'TotalCharges', data=churn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-8beec64aa080> in <module>()
#       1 #Boxplots
# ----> 2 sns.boxplot(x = 'PaymentMethod', y = 'TotalCharges', data=churn)
#
# D:\GEGDC\KT00475829\Anaconda\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# D:\GEGDC\KT00475829\Anaconda\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
# ...

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
churn['TotalCharges'].astype(str)
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
# 5         820.5
# 6        1949.4
# 7         301.9
# 8       3046.05
# 9       3487.95
# 10       587.45
# 11        326.8
# 12       5681.1
# 13       5036.3
# 14      2686.05
# 15      7895.15
# 16      1022.95
# 17      7382.25
# 18       528.35
# 19       1862.9
# 20        39.65
# 21       202.25
# 22        20.15
# 23       3505.1
# 24       2970.3
# 25       1530.6
# 26      4749.15
# 27         30.2
# 28      6369.45
# 29       1093.1
#          ...
# 7013     3756.4
# 7014    3645.75
# 7015    2874.45
# 7016      49.95
# 7017    1020.75
# 7018      70.65
# 7019        826
# 7020        239
# 7021      727.8
# 7022     7544.3
# 7023     6479.4
# 7024    3626.35
# 7025     1679.4
# 7026     403.35
# 7027     931.55
# 7028    4326.25
# 7029     263.05
# 7030      39.25
# 7031     3316.1
# 7032      75.75
# 7033    2625.25
# 7034    6886.25
# 7035     1495.1
# 7036      743.3
# ...

# %%
churn['TotalCharges'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e56e0edcf1b4> in <module>()
# ----> 1 churn['TotalCharges'].astype(int)
#
# D:\GEGDC\KT00475829\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# D:\GEGDC\KT00475829\Anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
tips = sns.load_dataset("tips")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\GEGDC\KT00475829\Anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# D:\GEGDC\KT00475829\Anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# D:\GEGDC\KT00475829\Anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# ...
